# %%
# !pip install -U huggingface_hub pillow python-dotenv
# Out:
# Requirement already satisfied: huggingface_hub in C:\Users\12146\anaconda3\Lib\site-packages (1.26.0)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.29.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pillow in C:\Users\12146\anaconda3\Lib\site-packages (10.4.0)
# Collecting pillow
#   Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: python-dotenv in C:\Users\12146\anaconda3\Lib\site-packages (0.21.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (4.70.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\12146\anaconda3\Lib\site-packages (from huggingface_hub) (4.16.0)
# Requirement already satisfied: colorama in C:\Users\12146\anaconda3\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface_hub) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\12146\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\12146\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\12146\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in C:\Users\12146\anaconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\12146\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Downloading huggingface_hub-1.29.0-py3-none-any.whl (795 kB)
#    ---------------------------------------- 0.0/795.8 kB ? eta -:--:--
#    ---------------------------------------- 795.8/795.8 kB 17.2 MB/s  0:00:00
# Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ------------------------ --------------- 4.5/7.2 MB 26.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 15.4 MB/s  0:00:00
# Downloading python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, pillow, huggingface_hub
#
#   Attempting uninstall: python-dotenv
#
#     Found existing installation: python-dotenv 0.21.0
#
#     Uninstalling python-dotenv-0.21.0:
#
#       Successfully uninstalled python-dotenv-0.21.0
#
#    ---------------------------------------- 0/3 [python-dotenv]
#   Attempting uninstall: pillow
#    ---------------------------------------- 0/3 [python-dotenv]
#     Found existing installation: pillow 10.4.0
#    ---------------------------------------- 0/3 [python-dotenv]
#    ------------- -------------------------- 1/3 [pillow]
#     Uninstalling pillow-10.4.0:
#    ------------- -------------------------- 1/3 [pillow]
#       Successfully uninstalled pillow-10.4.0
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#    ------------- -------------------------- 1/3 [pillow]
#   Attempting uninstall: huggingface_hub
#    ------------- -------------------------- 1/3 [pillow]
#     Found existing installation: huggingface_hub 1.26.0
#    ------------- -------------------------- 1/3 [pillow]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#     Uninstalling huggingface_hub-1.26.0:
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#       Successfully uninstalled huggingface_hub-1.26.0
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    -------------------------- ------------- 2/3 [huggingface_hub]
#    ---------------------------------------- 3/3 [huggingface_hub]
#
# Successfully installed huggingface_hub-1.29.0 pillow-12.3.0 python-dotenv-1.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.2.0 requires fsspec[http]<=2025.9.0,>=2023.1.0, but you have fsspec 2026.7.0 which is incompatible.
# mlflow-skinny 3.6.0 requires packaging<26, but you have packaging 26.2 which is incompatible.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 26.2 which is incompatible.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, but you have pillow 12.3.0 which is incompatible.
# streamlit 1.37.1 requires rich<14,>=10.14.0, but you have rich 15.0.0 which is incompatible.
# torchvision 0.23.0 requires torch==2.8.0, but you have torch 2.13.0 which is incompatible.
#
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\12146\anaconda3\Lib\site-packages (26.2)
# Collecting pip
#   Using cached pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.2.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.2
#     Uninstalling pip-26.2:
#       Successfully uninstalled pip-26.2
# Successfully installed pip-26.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
from pathlib import Path
from typing import Optional, Dict, Any

from dotenv import load_dotenv
from huggingface_hub import InferenceClient

# %%
# --------------------------------------------------
# Load environment variables
# --------------------------------------------------

load_dotenv()

HF_TOKEN = os.getenv("HF_TOKEN")

if not HF_TOKEN:
    raise RuntimeError(
        "HF_TOKEN was not found. "
        "Make sure HF_TOKEN is defined in your .env file."
    )

# %%
# --------------------------------------------------
# Hugging Face configuration
# --------------------------------------------------

MODEL_ID = "Wan-AI/Wan2.2-I2V-A14B"

hf_client = InferenceClient(
    token=HF_TOKEN
)
